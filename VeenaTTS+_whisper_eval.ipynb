# %% [markdown]
# <a href="https://colab.research.google.com/github/SujaAK/HindiASR/blob/main/VeenaTTS%2B_whisper_eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers torch torchaudio -q
# !pip install snac bitsandbytes -q
# !pip install soundfile -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 98.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.3/532.3 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 53.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 71.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.4 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall torch torchaudio torchvision -y -q
# !pip install torch==2.11.0+cu130 torchaudio==2.11.0+cu130 torchvision==0.27.0+cu130 --index-url https://download.pytorch.org/whl/cu130 -q
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 91.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 89.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 82.2 MB/s eta 0:00:00
# ERROR: Cannot install torch==2.11.0+cu130 and torchvision==0.27.0+cu130 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %%
# !pip install torch==2.11.0+cu130 torchaudio==2.11.0+cu130 --index-url https://download.pytorch.org/whl/cu130 -q
# !pip install torchvision --index-url https://download.pytorch.org/whl/cu130 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 70.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 74.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 59.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 59.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.1/531.1 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 73.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
# timm 1.0.27 requires torchvision, which is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 69.8 MB/s eta 0:00:00
# ...

# %%
# !pip install --force-reinstall --no-deps torch==2.11.0+cu130 torchaudio==2.11.0+cu130 torchvision==0.26.0+cu130 --index-url https://download.pytorch.org/whl/cu130 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.1/531.1 MB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 77.0 MB/s eta 0:00:00
# ERROR: Operation cancelled by user

# %%
import torch, torchaudio, torchvision
print("torch:", torch.__version__)
print("torchaudio:", torchaudio.__version__)
print("torchvision:", torchvision.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# torch: 2.11.0+cu128
# torchaudio: 2.11.0+cu128
# torchvision: 0.26.0+cu128
# CUDA available: True

# %%
from huggingface_hub import login
login()

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 60

# %%
# !pip install nvidia-cusparselt-cu13 -q

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from snac import SNAC

print("Loading Veena model...")
model = AutoModelForCausalLM.from_pretrained(
    "maya-research/veena-tts",
    dtype=torch.bfloat16,
    device_map="auto",
    trust_remote_code=True,
    low_cpu_mem_usage=True,
)
tokenizer = AutoTokenizer.from_pretrained("maya-research/veena-tts", trust_remote_code=True)

print("Loading SNAC decoder...")
snac_model = SNAC.from_pretrained("hubertsiuzdak/snac_24khz").eval().cuda()

print("All models loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1037/650123985.py in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 2 from snac import SNAC
#       3
#       4 print("Loading Veena model...")
#       5 model = AutoModelForCausalLM.from_pretrained(
#
# ModuleNotFoundError: No module named 'snac'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
START_OF_SPEECH_TOKEN = 128257
END_OF_SPEECH_TOKEN = 128258
START_OF_HUMAN_TOKEN = 128259
END_OF_HUMAN_TOKEN = 128260
START_OF_AI_TOKEN = 128261
END_OF_AI_TOKEN = 128262
AUDIO_CODE_BASE_OFFSET = 128266

def generate_speech(text, speaker="kavya", temperature=0.4, top_p=0.9):
    prompt = f"<spk_{speaker}> {text}"
    prompt_tokens = tokenizer.encode(prompt, add_special_tokens=False)

    input_tokens = [
        START_OF_HUMAN_TOKEN, *prompt_tokens, END_OF_HUMAN_TOKEN,
        START_OF_AI_TOKEN, START_OF_SPEECH_TOKEN
    ]
    input_ids = torch.tensor([input_tokens], device=model.device)
    max_tokens = min(int(len(text) * 1.3) * 7 + 21, 700)

    with torch.no_grad():
        output = model.generate(
            input_ids, max_new_tokens=max_tokens, do_sample=True,
            temperature=temperature, top_p=top_p, repetition_penalty=1.05,
            pad_token_id=tokenizer.pad_token_id,
            eos_token_id=[END_OF_SPEECH_TOKEN, END_OF_AI_TOKEN]
        )

    generated_ids = output[0][len(input_tokens):].tolist()
    snac_tokens = [t for t in generated_ids if AUDIO_CODE_BASE_OFFSET <= t < (AUDIO_CODE_BASE_OFFSET + 7*4096)]
    if not snac_tokens:
        raise ValueError("No audio tokens generated")
    return decode_snac_tokens(snac_tokens, snac_model)

def decode_snac_tokens(snac_tokens, snac_model):
    if not snac_tokens or len(snac_tokens) % 7 != 0:
        return None
    snac_device = next(snac_model.parameters()).device
    codes_lvl = [[] for _ in range(3)]
    offsets = [AUDIO_CODE_BASE_OFFSET + i * 4096 for i in range(7)]

    for i in range(0, len(snac_tokens), 7):
        codes_lvl[0].append(snac_tokens[i] - offsets[0])
        codes_lvl[1].append(snac_tokens[i+1] - offsets[1])
        codes_lvl[1].append(snac_tokens[i+4] - offsets[4])
        codes_lvl[2].append(snac_tokens[i+2] - offsets[2])
        codes_lvl[2].append(snac_tokens[i+3] - offsets[3])
        codes_lvl[2].append(snac_tokens[i+5] - offsets[5])
        codes_lvl[2].append(snac_tokens[i+6] - offsets[6])

    hierarchical_codes = []
    for lvl in codes_lvl:
        t = torch.tensor(lvl, dtype=torch.int32, device=snac_device).unsqueeze(0)
        hierarchical_codes.append(t)

    with torch.no_grad():
        audio_hat = snac_model.decode(hierarchical_codes)
    return audio_hat.squeeze().clamp(-1, 1).cpu().numpy()


import soundfile as sf

text_hindi = "नमस्ते, यह एक परीक्षण वाक्य है"
audio = generate_speech(text_hindi, speaker="kavya")
sf.write("test_veena.wav", audio, 24000)

import IPython.display as ipd
display(ipd.Audio("test_veena.wav"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1037/549490525.py in <cell line: 0>()
#      61
#      62 text_hindi = "नमस्ते, यह एक परीक्षण वाक्य है"
# ---> 63 audio = generate_speech(text_hindi, speaker="kavya")
#      64 sf.write("test_veena.wav", audio, 24000)
#      65
#
# /tmp/ipykernel_1037/549490525.py in generate_speech(text, speaker, temperature, top_p)
#       9 def generate_speech(text, speaker="kavya", temperature=0.4, top_p=0.9):
#      10     prompt = f"<spk_{speaker}> {text}"
# ---> 11     prompt_tokens = tokenizer.encode(prompt, add_special_tokens=False)
#      12
#      13     input_tokens = [
#
# NameError: name 'tokenizer' is not defined

# %%
# !pip uninstall torch torchaudio torchvision -y -q

# %%
# !pip install torch==2.11.0+cu128 torchaudio==2.11.0+cu128 torchvision==0.26.0+cu128 --index-url https://download.pytorch.org/whl/cu128 -q
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.3/820.3 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 49.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 43.7 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)

# %%
# !pip install snac bitsandbytes -q
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.3/532.3 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 750.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 111.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 68.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 1.5 MB/s eta 0:00:00
# ...

# %%
# !pip install openai-whisper -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 19.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import whisper

whisper_model = whisper.load_model("base")
result = whisper_model.transcribe(
    "test_veena.wav",
    language="hi",
    task="transcribe",
    initial_prompt="यह हिंदी में बातचीत है।"
)

print(f"Ground truth: {text_hindi}")
print(f"Whisper heard: {result['text']}")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:02<00:00, 54.1MiB/s]
# Ground truth: नमस्ते, यह एक परीक्षण वाक्य है
# Whisper heard:  नमस्ते, ये परीक्षन वाक क्या है।

# %%
test_sentences = [
    "मुझे दस लीटर दूध चाहिए सुबह सात बजे तक",
    "आपका पेमेंट पेंडिंग है, कृपया चालान भर दें",
    "डिलीवरी का समय बदलना है, क्या यह संभव है",
    "दुकान में आज पनीर और दही उपलब्ध है",
    "ग्राहक ने ऑर्डर कैंसिल करने के लिए कहा है",
]

speakers = ["kavya", "agastya", "maitri", "vinaya", "kavya"]

results = []
for i, (text, speaker) in enumerate(zip(test_sentences, speakers)):
    print(f"Generating sample {i} with speaker '{speaker}'...")
    audio = generate_speech(text, speaker=speaker)
    filename = f"test_sample_{i}.wav"
    sf.write(filename, audio, 24000)
    results.append({"text": text, "speaker": speaker, "file": filename})

print("\nAll samples generated. Now transcribing with Whisper...\n")

for r in results:
    result = whisper_model.transcribe(
        r["file"], language="hi", task="transcribe",
        initial_prompt="यह हिंदी में बातचीत है।"
    )
    print(f"Speaker: {r['speaker']}")
    print(f"GT:   {r['text']}")
    print(f"Pred: {result['text']}")
    print()
# Out:
# Generating sample 0 with speaker 'kavya'...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1037/3326651114.py in <cell line: 0>()
#      12 for i, (text, speaker) in enumerate(zip(test_sentences, speakers)):
#      13     print(f"Generating sample {i} with speaker '{speaker}'...")
# ---> 14     audio = generate_speech(text, speaker=speaker)
#      15     filename = f"test_sample_{i}.wav"
#      16     sf.write(filename, audio, 24000)
#
# NameError: name 'generate_speech' is not defined

# %%
# Try with lower temperature for more consistent/less random output
text_test = "मुझे दस लीटर दूध चाहिए सुबह सात बजे तक"
audio = generate_speech(text_test, speaker="kavya", temperature=0.2, top_p=0.85)
sf.write("retry_low_temp.wav", audio, 24000)

result = whisper_model.transcribe("retry_low_temp.wav", language="hi", task="transcribe",
                                     initial_prompt="यह हिंदी में बातचीत है।")
print(f"GT:   {text_test}")
print(f"Pred: {result['text']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1037/182535008.py in <cell line: 0>()
#       1 # Try with lower temperature for more consistent/less random output
#       2 text_test = "मुझे दस लीटर दूध चाहिए सुबह सात बजे तक"
# ----> 3 audio = generate_speech(text_test, speaker="kavya", temperature=0.2, top_p=0.85)
#       4 sf.write("retry_low_temp.wav", audio, 24000)
#       5
#
# NameError: name 'generate_speech' is not defined

# %%
import IPython.display as ipd

for r in results:
    print(f"Speaker: {r['speaker']}")
    print(f"Text: {r['text']}")
    display(ipd.Audio(r["file"]))
    print()
# Out:
# Speaker: kavya
# Text: मुझे दस लीटर दूध चाहिए सुबह सात बजे तक
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: agastya
# Text: आपका पेमेंट पेंडिंग है, कृपया चालान भर दें
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: maitri
# Text: डिलीवरी का समय बदलना है, क्या यह संभव है
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: vinaya
# Text: दुकान में आज पनीर और दही उपलब्ध है
# ...

# %%
whisper_model_large = whisper.load_model("small")  # or "medium" if your GPU has room

for r in results:
    result = whisper_model_large.transcribe(
        r["file"], language="hi", task="transcribe",
        initial_prompt="यह हिंदी में बातचीत है।"
    )
    print(f"Speaker: {r['speaker']}")
    print(f"GT:   {r['text']}")
    print(f"Pred (small): {result['text']}")
    print()
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:09<00:00, 50.5MiB/s]
# Speaker: kavya
# GT:   मुझे दस लीटर दूध चाहिए सुबह सात बजे तक
# Pred (small):  मुजे 10 लिटे दूग चाही सुब आद बजी तुध
#
# Speaker: agastya
# GT:   आपका पेमेंट पेंडिंग है, कृपया चालान भर दें
# Pred (small):  अपका पेमिंट पेंटिंग है, ख्रिप्या चालान बर दें।
#
# Speaker: maitri
# GT:   डिलीवरी का समय बदलना है, क्या यह संभव है
# Pred (small):  दीवरी का समवे बड़लना है, चा यह समवव है?
#
# Speaker: vinaya
# GT:   दुकान में आज पनीर और दही उपलब्ध है
# Pred (small):  दुकान में आज पनीर और दही उपलपदेर
#
# Speaker: kavya
# GT:   ग्राहक ने ऑर्डर कैंसिल करने के लिए कहा है
# Pred (small):  ग्राहक ने अडर कैंसल तरने किलि कहा है।

# %%
# !pip install jiwer -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 30.3 MB/s eta 0:00:00

# %%
import jiwer

references = [r["text"] for r in results]
predictions = []

for r in results:
    result = whisper_model_large.transcribe(
        r["file"], language="hi", task="transcribe",
        initial_prompt="यह हिंदी में बातचीत है।"
    )
    predictions.append(result["text"])

wer = jiwer.wer(references, predictions)
cer = jiwer.cer(references, predictions)

print(f"WER (whisper-small): {wer:.3f}")
print(f"CER (whisper-small): {cer:.3f}")
print(f"\n(Compare to whisper-base on same audio, and yesterday's WER 1.039/CER 0.886)")
# Out:
# WER (whisper-small): 0.674
# CER (whisper-small): 0.272
#
# (Compare to whisper-base on same audio, and yesterday's WER 1.039/CER 0.886)

# %%
print("--- Testing whisper-medium ---")
whisper_medium = whisper.load_model("medium")

predictions_medium = []
for r in results:
    result = whisper_medium.transcribe(
        r["file"], language="hi", task="transcribe",
        initial_prompt="यह हिंदी में बातचीत है।"
    )
    predictions_medium.append(result["text"])

wer_medium = jiwer.wer(references, predictions_medium)
cer_medium = jiwer.cer(references, predictions_medium)
print(f"WER (whisper-medium): {wer_medium:.3f}")
print(f"CER (whisper-medium): {cer_medium:.3f}")

for ref, pred in zip(references, predictions_medium):
    print(f"  GT:   {ref}")
    print(f"  Pred: {pred}")
# Out:
# --- Testing whisper-medium ---
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:27<00:00, 54.9MiB/s]
# WER (whisper-medium): 0.488
# CER (whisper-medium): 0.226
#   GT:   मुझे दस लीटर दूध चाहिए सुबह सात बजे तक
#   Pred:  मुझे 10 L दूट चाही हैं सोब 7 बजे त।
#   GT:   आपका पेमेंट पेंडिंग है, कृपया चालान भर दें
#   Pred:  आपका पेमेंट पेंडिंग है। क्रिप्या चालान भर दें।
#   GT:   डिलीवरी का समय बदलना है, क्या यह संभव है
#   Pred:  देवरी का समय बदलना हैं। च्या यह समभव हैं।
#   GT:   दुकान में आज पनीर और दही उपलब्ध है
#   Pred:  दुकान में आज पनीर और दही उपलबद है।
#   GT:   ग्राहक ने ऑर्डर कैंसिल करने के लिए कहा है
#   Pred:  ग्राहक ने आदर कानसिल करने के लिए कहा है।

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
import torch
import gc

for var_name in ["whisper_model", "whisper_model_large", "whisper_medium", "whisper_large"]:
    if var_name in dir():
        exec(f"del {var_name}")

torch.cuda.empty_cache()
gc.collect()
# Out:
# 85

# %%
import whisper

print("--- Testing whisper-large-v3 ---")
whisper_large = whisper.load_model("large-v3")

predictions_large = []
for r in results:
    result = whisper_large.transcribe(
        r["file"],
        language="hi",
        task="transcribe",
        initial_prompt="यह हिंदी में बातचीत है।"
    )
    predictions_large.append(result["text"])

wer_large = jiwer.wer(references, predictions_large)
cer_large = jiwer.cer(references, predictions_large)

print(f"WER (large-v3): {wer_large:.3f}")
print(f"CER (large-v3): {cer_large:.3f}")

for ref, pred in zip(references, predictions_large):
    print(f"GT:   {ref}")
    print(f"Pred: {pred}")
# Out:
# --- Testing whisper-large-v3 ---
# 100%|█████████████████████████████████████| 2.88G/2.88G [00:46<00:00, 67.1MiB/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1037/492693135.py in <cell line: 0>()
#       5
#       6 predictions_large = []
# ----> 7 for r in results:
#       8     result = whisper_large.transcribe(
#       9         r["file"],
#
# NameError: name 'results' is not defined

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4
